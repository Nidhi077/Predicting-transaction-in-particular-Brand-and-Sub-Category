# %%
from pyspark.sql import SparkSession

# initialise sparkContext

spark = SparkSession.builder \
    .master('local') \
    .appName('myAppName') \
    .config('spark.executor.memory', '5gb') \
    .config("spark.cores.max", "6") \
    .getOrCreate()

sc = spark.sparkContext

# using SQLContext to read parquet file

from pyspark.sql import SQLContext

sqlContext = SQLContext(sc)

# to read parquet file

# %%
bank = spark.read.csv("file:///C:/Users/ASUS/Documents/Bank_transaction/2_years.csv",inferSchema='True',header='True')

# %% [markdown]
# # Job Specification and data

# %%
data=bank['cid', 'amount', 'txn_date', 'Category', 'Sub_Category', 'Clean_Brand_Name']
# weekly, monthly, quarterly, yearly, overall
# overall category

job_specification = {'pkey': "cid", 'look_up_period': 3, 'information_variable': "amount", 'roll_up': "txn_date",
                     'dimension_variable': ["overall", "category"], 
                     'roll_up_level': ["overall", "weekly", "monthly","quarterly","yearly"], 
                       'features_type':['mean','median','max','min','count','std']}

# %%
sub_cat_list = ['Food']
brand_list = ["Haldiram's",
 'Independence Brewing Company',
 "McDonalds's",
 'Corner House Ice Cream']

# %% [markdown]
# # look_up function

# %% [markdown]
# This function has input of lookup period and the data, it performs following functions
#
#
#  1- It filters the data according to the given look up period and converts the columns of the raw input to lower cases to avoid any issues in the input.
#
#  2- It makes new coloumns of month ,day, year ,quarter,weekday, weekend and the following coloumns are attached to the     dataset
#
#  3- The data set is returned.

# %%
def look_up(time_period,df,date_variable):
    import datetime
    from pyspark.sql import functions as F
    from pyspark.sql.functions import year, to_date, month, dayofmonth, dayofweek, quarter
    from itertools import chain
    #converting column name to lower case
    for col in df.columns:
        df = df.withColumnRenamed(col, col.lower())
    now = datetime.datetime.now()
    current_year = now.year
    years = []
    months_list = []
    for i in range(current_year-(time_period-1),current_year+1):
        print(i)
        years.append(i)    
    df = df.withColumn(
      "txn_year",
      year(F.col(date_variable))
    ).withColumn(
      "txn_month",
      month(F.col(date_variable))
    ).withColumn(
      "txn_day",
      dayofmonth(F.col(date_variable))
    ).withColumn(
      "txn_weekday",
        dayofweek(F.col(date_variable))
    ).withColumn(
        "txn_quarter",
        quarter(F.col(date_variable))
    )
   
    df = df[df['txn_year'].isin(years)]
    mapping_week = {2: 'weekday',3: 'weekday', 4: 'weekday',5: 'weekday',6: 'weekday',1: 'weekend', 7: 'weekend'}
    mapping_quarter = {1: 'quarter_1', 2: 'quarter_2', 3: 'quarter_3', 4: 'quarter_4'}
    mapping_month = {1: 'Jan', 2: 'Feb' , 3: 'Mar' , 4: 'Apr' , 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct',
                     11: 'Nov', 12: 'Dec'}

    map_week = F.create_map([F.lit(x) for x in chain(*mapping_week.items())])
    map_quarter =  F.create_map([F.lit(x) for x in chain(*mapping_quarter.items())])
    map_month = F.create_map([F.lit(x) for x in chain(*mapping_month.items())])

    df = df.withColumn('weekend_weekday', map_week[df['txn_weekday']])
    df = df.withColumn('txn_quarter', map_quarter[df['txn_quarter']])
    df = df.withColumn('txn_month', map_month[df['txn_month']])
    return df

# %% [markdown]
# # Concatenates two columns

# %%
def col(df, x,y):
    from pyspark.sql import functions as F
    name = x + '_' + y
    df= df.withColumn(name, F.concat(F.col(x),F.lit('_'), F.col(y)))
    return df, name

# %% [markdown]
# # Modifying column names

# %%
def rename(df):
    def col_name(column):
        new = ''
        for i in column:
            if i == '(':
                break
            else:
                new += i
        return new  
    for i in df.columns:
        df = df.withColumnRenamed(i , col_name(i))
    return df

# %% [markdown]
# # Delete columns with nan or null in them

# %%
def del_nan(df):
    for i in df.columns:
        if (('null' in i) == True):
            df = df.drop(i) 
        elif (('nan' in i) == True):
            df = df.drop(i)     
    return df

# %% [markdown]
# # Expenditure function

# %% [markdown]
# This function calculates the feature as a whole .

# %%
def expenditure(df,id,amount):
    from pyspark.sql import functions as F
    expend = df.groupBy(df[id]).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
    
    for i in range(1,len(expend.columns)):
        new="overall_"
        for k in expend.columns[i]:
            if k == '(':
                break
            else:
                new += k
        expend = expend.withColumnRenamed(expend.columns[i],new)
    return expend

# %% [markdown]
# # each_customer_transaction

# %% [markdown]
# This function creates feature in customer level , it returns 4 data frames:
#
#
# 1- yearly transaction features
#
# 2- monthly transaction features
#
# 3- weekly (weekday and weekend) transaction features
#
# 4- quarterly

# %%
def each_customer_transaction(df,id,amount):
    from pyspark.sql import functions as F
    dataframes = []
    df, column = col(df, 'txn_year', 'txn_month')#call to col function that concatenates coloumn to dataframes
    for i in job_specification['roll_up_level']:
        
        
        if (i == 'weekly'): 
            df, column = col(df, column, 'weekend_weekday')
            weekly = df.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
            weekly = rename(weekly) 
            weekly = del_nan(weekly)
            dataframes.append(weekly)
            
        elif (i == 'monthly'):
            df, column = col(df, 'txn_year', 'txn_month')
            monthly = df.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
            monthly = rename(monthly)
            monthly = del_nan(monthly)
            dataframes.append(monthly)

        elif (i == 'quarterly'):
            df, column = col(df, 'txn_year', 'txn_quarter')
            quarterly=df.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
            quarterly = rename(quarterly)
            quarterly = del_nan(quarterly)
            dataframes.append(quarterly)
        elif (i == 'yearly'):
            yearly = df.groupby(id).pivot('txn_year').agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
            yearly = rename(yearly)
            yearly = del_nan(yearly)
            dataframes.append(yearly)
     
    return  dataframes

# %% [markdown]
# # Category

# %%
def category(df,id,dim,amount):
    from pyspark.sql import functions as F
    dataframes = []
    for i in job_specification['roll_up_level']:
        if (i == 'overall'):
            overall = df.groupby(id).pivot(dim).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
            overall = rename(overall)
            overall = del_nan(overall)
            for i in range(1,len(overall.columns)):
                    new="overall_"+overall.columns[i]
                    overall = overall.withColumnRenamed(overall.columns[i] , new)
            dataframes.append(overall)
            
        elif(i == 'quarterly'):
        
            df, column = col(df, 'txn_year', 'txn_quarter')
            df, column = col(df, column, 'category')
            quarterly = df.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
            quarterly = rename(quarterly)
            quarterly = del_nan(quarterly)
            dataframes.append(quarterly)
            
        elif(i == 'yearly'):
            df, column = col(df, 'txn_year', dim)
            yearly = df.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
            yearly = rename(yearly)
            yearly = del_nan(yearly)
            dataframes.append(yearly)
            
    return  dataframes

# %% [markdown]
# # Sub Category

# %%
def cat_sub(df,id,category,amount):
        from pyspark.sql import functions as F 
        df = df[df['category'].isin(category)]
        dataframes = []
        df, column = col(df, 'category', 'sub_category')
        for i in job_specification['roll_up_level']:
            if (i == 'overall'):
                df, column = col(df, 'category', 'sub_category')
                overall = df.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
                overall = rename(overall)
                overall = del_nan(overall)
                for i in range(1,len(overall.columns)):
                        new="overall_"+overall.columns[i]
                        overall = overall.withColumnRenamed(overall.columns[i] , new)         
                dataframes.append(overall)
            
            elif (i == 'quarterly'):
                df, column = col(df, 'category', 'sub_category')
                df, column = col(df, column, 'txn_year')
                df, column = col(df, column, 'txn_quarter')
                quarterly = df.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
                quarterly = rename(quarterly)
                quarterly = del_nan(quarterly)
                dataframes.append(quarterly)
                
            elif (i == 'yearly'):
                df, column = col(df, 'category', 'sub_category')
                df, column = col(df, column, 'txn_year')
                yearly = df.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
                yearly = rename(yearly)
                yearly = del_nan(yearly)
                dataframes.append(yearly)
            
        return  dataframes

# %% [markdown]
# # Brand

# %%
def cat_brand(df,id,brands,amount):
        from pyspark.sql import functions as F
        df = df[df['clean_brand_name'].isin(brands)]
        dataframes = []
        for i in brands:
            new = i + '_' + 'brand'
            new = df[df['clean_brand_name'].isin(i)]
            for j in job_specification['roll_up_level']:
                if (j == 'quarterly'):
                    #quar = i + '_' + 'quarter'
                    new, column = col(new, 'clean_brand_name', 'txn_year')
                    new, column = col(new, column, 'txn_quarter')
                    quarterly = new.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
                    quarterly = rename(quarterly)
                    dataframes.append(quarterly)
                elif (j == 'yearly'):

                    new, column = col(new, 'clean_brand_name', 'txn_year')
                    #year = i + '_' + 'year'
                    yearly = new.groupby(id).pivot(column).agg(F.sum(amount),F.mean(amount),F.max(amount),F.min(amount),
                                          F.count(amount),F.stddev(amount))
                    yearly  = rename(yearly)
                    dataframes.append(yearly)
        
        return  dataframes

# %% [markdown]
# # Check empty list

# %%
def isempty(list):
    if(len(list)==0):
        return 1
    else:
        return 0

# %% [markdown]
# # Join all dataframes

# %%
def join_df(dataframe, id):
    df = dataframe[0]
    for i in range(len(dataframe)-1):
        df = df.join(dataframe[i+1], on= id, how='outer')
    return df

# %% [markdown]
# # Start Function

# %%
def startfun(df,job_specification,sub_cat_list,brand_list):
    #LOOKUP FUNCTION
    new_data=look_up(job_specification['look_up_period'],df,job_specification['roll_up'])
    
    #EXPENDITURE
    exp=expenditure(new_data,job_specification['pkey'],job_specification['information_variable'])
    dataframes = [exp]
    
    #EACH CUSTOMER
    for i in job_specification['dimension_variable']:
        if i=='overall':
            cus_transaction = each_customer_transaction(new_data,job_specification['pkey'],job_specification['information_variable'])
            for i in cus_transaction:
                dataframes.append(i)
    
    # CATEGORY
        elif i=='category':
            categories = category(new_data, job_specification['pkey'],i,job_specification['information_variable'])
            for i in categories:
                dataframes.append(i)
    # SUBCATEGORY
    if not(isempty(sub_cat_list)):
        sub_category = cat_sub(new_data,job_specification['pkey'],sub_cat_list,job_specification['information_variable'])
        for i in sub_category:
            dataframes.append(i)
    # BRAND
    if not(isempty(brand_list)):
        brands = cat_brand(new_data,job_specification['pkey'],brand_list,job_specification['information_variable'])
        for i in brands:
            dataframes.append(i)
    
    concat_df = join_df(dataframes, job_specification['pkey'])
    concat_df = concat_df.toDF(*[c.lower() for c in concat_df.columns])
    
    return dataframes, concat_df

# %% [markdown]
# # This is the call to our starter function and it displays all the keys

# %%
import time

# %%
start = time.time()
df_list, feature_df = startfun(data,job_specification,sub_cat_list,brand_list)
print('Duration: {} seconds'.format(time.time() - start))
# Out:
# 2018
# 2019
# 2020
# Duration: 124.93029808998108 seconds

# %%
start = time.time()
merged_data.show()
print('Duration: {} seconds'.format(time.time() - start))
# Out:
# +----+-----------+------------------+-----------+-----------+-------------+-------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+------------- ...
# | cid|overall_sum|       overall_avg|overall_max|overall_min|overall_count|overall_stddev_samp|2019_apr_weekday_sum|2019_apr_weekday_avg|2019_apr_weekday_max|2019_apr_weekday_min|2019_apr_weekday_count|2019_apr_weekday_stddev_samp|2019_apr_weekend_sum|2019_apr_weekend_avg|2019_apr_weekend_max|2019_apr_weekend_min|2019_apr_weekend_count|2019_apr_weekend_stddev_samp|2019_aug_weekday_sum|2019_aug_weekday_avg|2019_aug_weekday_max|2019_aug_weekday_min|2019_aug_weekday_count|2019_aug_weekday_stddev_samp|2019_aug_weekend_sum|2019_aug_weekend_avg|2019_aug_weekend_max|2019_aug_weekend_min|2019_aug_weekend_count|2019_aug_weekend_stddev_samp|2019_dec_weekday_sum|2019_dec_weekday_avg|2019_dec_weekday_max|2019_dec_weekday_min|2019_dec_weekday_count|2019_dec_weekday_stddev_samp|2019_dec_weekend_sum|2019_dec_weekend_avg|2019_dec_weekend_max|2019_dec_weekend_min|2019_dec_weekend_count|2019_dec_weekend_stddev_samp|2019_feb_weekday_sum|2019_feb_weekday_avg|2019_feb_weekday_max|2019_feb_weekday_min|2019_feb_weekday_count|2019_feb_weekday_stddev_samp|2019_feb_weekend_sum|2019_feb_weekend_avg|2019_feb_weekend_max|2019_feb_weekend_min|2019_feb_weekend_count|2019_feb_weekend_stddev_samp|2019_jan_weekday_sum|2019_jan_weekday_avg|2019_jan_weekday_max|2019_jan_weekday_min|2019_jan_weekday_count|2019_jan_weekday_stddev_samp|2019_jan_weekend_sum|2019_jan_weekend_avg|2019_jan_weekend_max|2019_jan_weekend_min|2019_jan_weekend_count|2019_jan_weekend_stddev_samp|2019_jul_weekday_sum|2019_jul_weekday_avg|2019_jul_weekday_max|2019_jul_weekday_min|2019_jul_weekday_count|2019_jul_weekday_stddev_samp|2019_jul_weekend_sum|2019_jul_weekend_avg|2019_jul_weekend_max|2019_jul_weekend_min|2019_jul_weekend_count|2019_jul_weekend_stddev_samp|2019_jun_weekday_sum|2019_jun_weekday_avg|2019_jun_weekday_max|2019_jun_weekday_min|2019_jun_weekday_count|2019_jun_weekday_stddev_samp|2019_jun_weekend_sum|2019_jun_weekend_avg|2019_jun_weekend_max|2019_jun_weekend_min|2019_jun_weekend_count|2019_jun_weekend_stddev_samp|2019_mar_weekday_sum|2019_mar_weekday_avg|2019_mar_weekday_max|2019_mar_weekday_min|2019_mar_weekday_count|2019_mar_weekday_stddev_samp|2019_mar_weekend_sum|2019_mar_weekend_avg|2019_mar_weekend_max|2019_mar_weekend_min|2019_mar_weekend_count|2019_mar_weekend_stddev_samp|2019_may_weekday_sum|2019_may_weekday_avg|2019_may_weekday_max|2019_may_weekday_min|2019_may_weekday_count|2019_may_weekday_stddev_samp|2019_may_weekend_sum|2019_may_weekend_avg|2019_may_weekend_max|2019_may_weekend_min|2019_may_weekend_count|2019_may_weekend_stddev_samp|2019_nov_weekday_sum|2019_nov_weekday_avg|2019_nov_weekday_max|2019_nov_weekday_min|2019_nov_weekday_count|2019_nov_weekday_stddev_samp|2019_nov_weekend_sum|2019_nov_weekend_avg|2019_nov_weekend_max|2019_nov_weekend_min|2019_nov_weekend_count|2019_nov_weekend_stddev_samp|2019_oct_weekday_sum|2019_oct_weekday_avg|2019_oct_weekday_max|2019_oct_weekday_min|2019_oct_weekday_count|2019_oct_weekday_stddev_samp|2019_oct_weekend_sum|2019_oct_weekend_avg|2019_oct_weekend_max|2019_oct_weekend_min|2019_oct_weekend_count|2019_oct_weekend_stddev_samp|2019_sep_weekday_sum|2019_sep_weekday_avg|2019_sep_weekday_max|2019_sep_weekday_min|2019_sep_weekday_count|2019_sep_weekday_stddev_samp|2019_sep_weekend_sum|2019_sep_weekend_avg|2019_sep_weekend_max|2019_sep_weekend_min|2019_sep_weekend_count|2019_sep_weekend_stddev_samp|2020_apr_weekday_sum|2020_apr_weekday_avg|2020_apr_weekday_max|2020_apr_weekday_min|2020_apr_weekday_count|2020_apr_weekday_stddev_samp|2020_apr_weekend_sum|2020_apr_weekend_avg|2020_apr_weekend_max|2020_apr_weekend_min|2020_apr_weekend_count|2020_apr_weekend_stddev_samp|2020_feb_weekday_sum|2020_feb_weekday_avg|2020_feb_weekday_max|2020_feb_weekday_min|2020_feb_weekday_count|2020_feb_weekday_stddev_samp|2020_feb_weekend_sum|2020_feb_weekend_avg|2020_feb_weekend_max|2020_feb_weekend_min|2020_feb_weekend_count|2020_feb_weekend_stddev_samp|2020_jan_weekday_sum|2020_jan_weekday_avg|2020_jan_weekday_max|2020_jan_weekday_min|2020_jan_week ...
# +----+-----------+------------------+-----------+-----------+-------------+-------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+------------- ...
# |1090|     1493.0|             298.6|         75|          1|            5|  259.7042548746555|               637.0|               637.0|                 637|                 637|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|               390.0|               390.0|                 390|                 390|                     1|                         NaN|                76.0|                38.0|                  75|                   1|                     2|           52.32590180780452|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|               390.0|               390.0|                 390|                 390|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|              ...
# |1159|   133563.0|2841.7659574468084|       9500|       1010|           47|  2085.340074578244|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|             47558.0|            2972.375|                 791|                3780|                    16|           1895.672892844825|             10686.0|              5343.0|                9500|                1186|                     2|          5878.8857787849565|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|             10500.0|              3500.0|                4500|                2000|                     3|          1322.8756555322952|              5004.0|              2502.0|                 510|                4494|                     2|          2817.1134162472054|             45835.0|  2412.3684210526317|                 885|                1010|              ...
# |1512|   854773.0|3833.0627802690583|        998|          1|          223|  9895.855343881693|             39086.0|  1447.6296296296296|                 997|                 101|                    27|          1594.0828843461188|             20917.0|   6972.333333333333|                 917|               15000|                     3|           7245.708822008605|             88251.0|           11031.375|                 965|                 117|                     8|          29889.107408827527|               235.0|               235.0|                 235|                 235|                     1|                         NaN|             83876.0|   9319.555555555555|                 868|                 100|                     9|          16993.387442701875|               200.0|               200.0|                 200|                 200|                     1|                         NaN|             20366.0|  1697.1666666666667|                 586|                1220|                    12|           1543.821576674604|             10405.0|            1300.625|                 840|                1880|                     8|           750.9062976544695|             19869.0|  2207.6666666666665|                9000|                   1|                     9|            3600.02267353971|              9316.0|              1863.2|                 903|                1340|                     5|          1805.3508523276025|             11599.0|             2899.75|                8982|                1012|                     4|           4060.865784123709|             30000.0|             15000.0|               20000|               10000|                     2|           7071.067811865475|             54454.0|              5445.4|                8000|               10463|                    10|           5714.326521997146|              1308.0|               654.0|                 220|                1088|                     2|           613.7686860699232|             16742.0|  2790.3333333333335|                 811|                1911|                     6|          2249.1901357303404|             21300.0|  2366.6666666666665|                 953|                2000|                     9|          2034.2263271327504|             69118.0|   5759.833333333333|                9000|                  10|                    12|           7182.328830138761|               470.0|               470.0|                 470|                 470|                     1|                         NaN|              8470.0|             1058.75|                 991|                1050|                     8|            895.073620276168|              8193.0|             2048.25|                2715|                1056|                     4|           723.6787385758039|            102535.0|   5696.388888888889|                 998|                 129|                    18|           16425.02655433036|              1033.0|   344.3333333333333|                 676|                 158|                     3|           287.9623818024384|            107035.0|   9730.454545454546|                 800|                1136|                    11|          16317.299631762826|              2211.0|               442.2|                 657|                 135|                     5|          194.13706498244994|              1068.0|               534.0|                 858|                 210|                     2|           458.2051942088828|               688.0|  229.33333333333334|                 530|                 129|                     3|          265.14210026575057|              2136.0|               712.0|                 300|                1627|                     3|           793.7184639404579|              4386.0|              4386.0|                4386|                4386|                     1|                         NaN|            108264.0|              6766.5|                 868|               10200|              ...
# |1572|    29268.0|2090.5714285714284|        985|       1400|           14| 2071.4553677690815|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              3990.0|              3990.0|                3990|                3990|                     1|                         NaN|             11913.0|              2382.6|                 625|                1400|                     5|          1308.5403318201545|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              7000.0|              7000.0|                7000|                7000|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              4330.0|              2165.0|                 420|                3910|                     2|           2467.802666341051|              2010.0|               502.5|                 985|                 225|                     4|           336.9594436525955|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|              ...
# |2069|    19391.0|         1211.9375|        940|       1160|           16|  790.2380627591493|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                47.0|                47.0|                  47|                  47|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              2981.0|              1490.5|                1581|                1400|                     2|           127.9863273947651|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              1612.0|              1612.0|                1612|                1612|                     1|                         NaN|              4440.0|              1480.0|                 940|                1500|                     3|            530.282943342514|              2559.0|               853.0|                 624|                1410|                     3|          484.90926986396124|                null|                null|                null|                null|                     0|                        null|               910.0|               455.0|                 831|                  79|                     2|           531.7442994522837|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              4482.0|              2241.0|                3322|                1160|                     2|          1528.7648609253158|               899.0|               899.0|                 899|                 899|              ...
# |2088|   824531.0|21698.184210526317|       9000|       1000|           38|  50560.01951753774|             14410.0|  2401.6666666666665|                4885|                1080|                     6|           1304.345455263546|               298.0|               298.0|                 298|                 298|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              6963.0|              6963.0|                6963|                6963|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|             45990.0|             45990.0|               45990|               45990|                     1|                         NaN|             29000.0|   9666.666666666666|                9000|               10000|                     3|           577.3502691896258|               500.0|               500.0|                 500|                 500|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              8267.0|            1033.375|                 835|                1200|                     8|          466.74004312587414|              1609.0|               804.5|                 609|                1000|                     2|           276.4787514439401|              9010.0|              4505.0|                8630|                 380|                     2|           5833.630944789017|            104643.0|             34881.0|                2643|              100000|                     3|           56395.62467957953|               322.0|               322.0|                 322|                 322|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|            267776.0|            133888.0|              250000|               17776|                     2|           164207.1651542648|                null|                null|                null|                null|                     0|                        null|             23950.0|             11975.0|                2450|               21500|                     2|          13470.384181603731|               365.0|               365.0|                 365|                 365|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|              6968.0|              6968.0|                6968|                6968|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|             76380.0|             76380.0|               76380|               76380|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|            228080.0|            114040.0|               65500|              162580|              ...
# |2136|   751729.0| 1630.648590021692|        999|         10|          461|  2208.732652091802|             24279.0|           1517.4375|                 804|                1153|                    16|          1708.9859749278226|             19664.0|              1966.4|                 999|                 130|                    10|          2673.5884832520087|             37781.0|   1799.095238095238|                 999|               10500|                    21|          2392.9492870673607|             37450.0|   2880.769230769231|                 837|               10000|                    13|           3704.929624924207|             64477.0|   2223.344827586207|                 948|               10000|                    29|          3117.4730182800995|             31540.0|  2867.2727272727275|                  75|                 121|                    11|          3910.9010493979285|             14255.0|  1096.5384615384614|                 995|                1296|                    13|          1874.3626301307781|              7384.0|               923.0|                 704|                 109|                     8|           753.6645710886811|             14472.0|               804.0|                 999|                1255|                    18|          480.73436470858275|              7449.0|              2483.0|                 650|                 599|                     3|          3219.1174256308204|             28850.0|  1697.0588235294117|                 873|                  10|                    17|          2583.0431294934915|             12533.0|  1392.5555555555557|                 910|                1120|                     9|            1231.87865789524|             32629.0|  1418.6521739130435|                 999|                  10|                    23|          1738.8856047035006|             23385.0|              1559.0|                   8|                1012|                    15|          2424.7267003579127|             16690.0|               834.5|                 860|                 135|                    20|           677.0250325777047|             11261.0|   804.3571428571429|                  92|                1000|                    14|           591.1680233809436|             25130.0|  1675.3333333333333|                 945|                1480|                    15|           2070.669031519822|             11340.0|              1890.0|                3625|                 125|                     6|          1441.1167891604066|             30296.0|  1262.3333333333333|                 999|                1335|                    24|           991.8591969965628|             10385.0|   1153.888888888889|                 950|                 149|                     9|          1247.0510659596546|             18126.0|               954.0|                 999|                 105|                    19|           954.5650551138169|             38684.0|              3868.4|                 905|               10000|                    10|           3606.770214163605|             65909.0|  2353.8928571428573|                 999|                 100|                    28|           3703.935517990097|              7536.0|              1256.0|                 649|                2150|                     6|          1213.2805116707348|             33362.0|   2224.133333333333|                 822|                1828|                    15|          2002.5595360033856|              6309.0|              2103.0|                3399|                1107|                     3|          1175.0812737849242|             18748.0|  1102.8235294117646|                 999|                1284|                    17|          1113.8917269698006|             10663.0|            1332.875|                 822|                 100|                     8|           1753.050845770636|             34947.0|              1941.5|                9490|                1043|              ...
# |2294|    98211.0|2888.5588235294117|        820|       1597|           34| 3554.4418663530596|               169.0|               169.0|                 169|                 169|                     1|                         NaN|              5000.0|              5000.0|                5000|                5000|                     1|                         NaN|             36363.0|            4545.375|                5000|                1597|                     8|           6604.202102503699|               820.0|               820.0|                 820|                 820|                     1|                         NaN|               730.0|               365.0|                 430|                 300|                     2|           91.92388155425118|                null|                null|                null|                null|                     0|                        null|              4000.0|              2000.0|                2000|                2000|                     2|                         0.0|                null|                null|                null|                null|                     0|                        null|              8000.0|              2000.0|                2000|                2000|                     4|                         0.0|                null|                null|                null|                null|                     0|                        null|             20649.0|            2581.125|                5000|                1900|                     8|          1797.7903451181398|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              5000.0|              5000.0|                5000|                5000|                     1|                         NaN|              7000.0|              3500.0|                5000|                2000|                     2|          2121.3203435596424|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              5000.0|              5000.0|                5000|                5000|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|               300.0|               300.0|                 300|                 300|                     1|                         NaN|              5180.0|              2590.0|                5000|                 180|                     2|           3408.254685319159|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|              ...
# ...
# | 675|   203199.0| 1527.812030075188|        861|       1000|          133|  2928.779379501564|             15500.0|             15500.0|               15500|               15500|                     1|                         NaN|              2309.0|              577.25|                 534|                1320|                     4|           517.5940333247025|              9203.0|  3067.6666666666665|                6743|                 220|                     3|           3339.334714180855|               246.0|               246.0|                 246|                 246|                     1|                         NaN|              1699.0|              424.75|                 861|                 178|                     4|           300.5299485908185|              2142.0|              1071.0|                 641|                1501|                     2|           608.1118318204309|             19801.0|              9900.5|                7430|               12371|                     2|          3493.8146058427315|              1270.0|               635.0|                 750|                 520|                     2|          162.63455967290594|              2058.0|              1029.0|                 563|                1495|                     2|           659.0235200658623|              4039.0|               807.8|                 799|                1300|                     5|           647.9708326769038|              5077.0|              1015.4|                  60|                 132|                     5|          1307.5656006487782|              5421.0|              1084.2|                 557|                1975|                     5|          1042.1644304043389|                null|                null|                null|                null|                     0|                        null|               597.0|               298.5|                 397|                 200|                     2|          139.30003589374985|              9001.0|  1500.1666666666667|                7241|                 208|                     6|          2818.9397593185045|               250.0|               250.0|                 250|                 250|                     1|                         NaN|               379.0|  54.142857142857146|                  64|                 135|                     7|           37.30696347613303|              4275.0|             534.375|                  80|                1273|                     8|           612.3451261922712|              1026.0|               342.0|                 460|                 270|                     3|          103.01456207740729|               922.0|   307.3333333333333|                 555|                 118|                     3|          224.26398135530667|             39012.0|              3251.0|                 650|                1000|                    12|           4648.377781549172|              9138.0|              1827.6|                5000|                1000|                     5|          2086.3290248664043|              1088.0|               217.6|                 350|                 135|                     5|           88.24001359927365|              5612.0|   623.5555555555555|                  55|                1000|                     9|           611.0399150446539|               110.0|                27.5|                  33|                  22|                     4|          6.3508529610858835|              1366.0|   455.3333333333333|                 671|                  33|                     3|           365.7790772219392|              7437.0|              3718.5|                7003|                 434|                     2|           4644.984445614431|             23386.0|   7795.333333333333|                6835|               16310|                     3|            8077.42968606557|              9696.0|              3232.0|                5870|                1682|              ...
# | 691|    74883.0| 902.2048192771084|        999|          1|           83| 1553.9850248755508|             10264.0|  1140.4444444444443|                 840|                1070|                     9|           782.6472882325587|               574.0|               287.0|                 319|                 255|                     2|          45.254833995939045|               885.0|              221.25|                 468|                   2|                     4|          239.68503638455752|              1329.0|               664.5|                 250|                1079|                     2|           586.1915216036479|              2818.0|               563.6|                 995|                 240|                     5|           282.4753086554646|              6466.0|              1293.2|                 585|                1504|                     5|           1433.434232882695|               930.0|               465.0|                 470|                 460|                     2|          7.0710678118654755|              1880.0|               940.0|                 780|                1100|                     2|          226.27416997969522|              4739.0|               677.0|                 770|                  10|                     7|           848.7685196801305|             13680.0|              4560.0|                 685|               12410|                     3|           6798.483286733887|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              1331.0|               665.5|                 674|                 657|                     2|          12.020815280171307|              2670.0|               445.0|                 970|                 150|                     6|          354.05423313385194|              3531.0|  504.42857142857144|                 999|                 222|                     7|          256.31546782747824|              1199.0|               599.5|                 739|                 460|                     2|          197.28279195104676|               725.0|               725.0|                 725|                 725|                     1|                         NaN|              3794.0|              1897.0|                3606|                 188|                     2|          2416.8909780956196|              2051.0|   341.8333333333333|                  55|                 205|                     6|          199.16366803879333|              2985.0|              2985.0|                2985|                2985|                     1|                         NaN|              7413.0|             1853.25|                 984|                 448|                     4|          2406.6545763777567|              1530.0|               765.0|                 330|                1200|                     2|           615.1828996322963|               275.0|               137.5|                 274|                   1|                     2|          193.04015126392747|               803.0|               803.0|                 803|                 803|                     1|                         NaN|                null|                null|                null|                null|                     0|                        null|                null|                null|                null|                null|                     0|                        null|              1178.0|               589.0|                 655|                 523|                     2|           93.33809511662427|               460.0|               460.0|                 460|                 460|                     1|                         NaN|              1005.0|               502.5|                 800|                 205|              ...
# +----+-----------+------------------+-----------+-----------+-------------+-------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+------------- ...
# only showing top 20 rows
#
# Duration: 464.84519243240356 seconds

# %% [markdown]
# # Total number of new columns are:

# %%
len(feature_df.columns)
# Out:
# 2461

# %%
print(feature_df.columns)
# Out:
# ['cid', 'overall_sum', 'overall_avg', 'overall_max', 'overall_min', 'overall_count', 'overall_stddev_samp', '2018_aug_weekday_sum', '2018_aug_weekday_avg', '2018_aug_weekday_max', '2018_aug_weekday_min', '2018_aug_weekday_count', '2018_aug_weekday_stddev_samp', '2018_aug_weekend_sum', '2018_aug_weekend_avg', '2018_aug_weekend_max', '2018_aug_weekend_min', '2018_aug_weekend_count', '2018_aug_weekend_stddev_samp', '2018_dec_weekday_sum', '2018_dec_weekday_avg', '2018_dec_weekday_max', '2018_dec_weekday_min', '2018_dec_weekday_count', '2018_dec_weekday_stddev_samp', '2018_dec_weekend_sum', '2018_dec_weekend_avg', '2018_dec_weekend_max', '2018_dec_weekend_min', '2018_dec_weekend_count', '2018_dec_weekend_stddev_samp', '2018_jul_weekday_sum', '2018_jul_weekday_avg', '2018_jul_weekday_max', '2018_jul_weekday_min', '2018_jul_weekday_count', '2018_jul_weekday_stddev_samp', '2018_jul_weekend_sum', '2018_jul_weekend_avg', '2018_jul_weekend_max', '2018_jul_weekend_min', '2018_jul_weekend_count', '2018_jul_weekend_stddev_samp', '2018_jun_weekday_sum', '2018_jun_weekday_avg', '2018_jun_weekday_max', '2018_jun_weekday_min', '2018_jun_weekday_count', '2018_jun_weekday_stddev_samp', '2018_jun_weekend_sum', '2018_jun_weekend_avg', '2018_jun_weekend_max', '2018_jun_weekend_min', '2018_jun_weekend_count', '2018_jun_weekend_stddev_samp', '2018_nov_weekday_sum', '2018_nov_weekday_avg', '2018_nov_weekday_max', '2018_nov_weekday_min', '2018_nov_weekday_count', '2018_nov_weekday_stddev_samp', '2018_nov_weekend_sum', '2018_nov_weekend_avg', '2018_nov_weekend_max', '2018_nov_weekend_min', '2018_nov_weekend_count', '2018_nov_weekend_stddev_samp', '2018_oct_weekday_sum', '2018_oct_weekday_avg', '2018_oct_weekday_max', '2018_oct_weekday_min', '2018_oct_weekday_count', '2018_oct_weekday_stddev_samp', '2018_oct_weekend_sum', '2018_oct_weekend_avg', '2018_oct_weekend_max', '2018_oct_weekend_min', '2018_oct_weekend_count', '2018_oct_weekend_stddev_samp', '2018_sep_weekday_sum', '2018_sep_weekday_avg', '2018_sep_weekday_max', '2018_sep_weekday_min', '2018_sep_weekday_count', '2018_sep_weekday_stddev_samp', '2018_sep_weekend_sum', '2018_sep_weekend_avg', '2018_sep_weekend_max', '2018_sep_weekend_min', '2018_sep_weekend_count', '2018_sep_weekend_stddev_samp', '2019_apr_weekday_sum', '2019_apr_weekday_avg', '2019_apr_weekday_max', '2019_apr_weekday_min', '2019_apr_weekday_count', '2019_apr_weekday_stddev_samp', '2019_apr_weekend_sum', '2019_apr_weekend_avg', '2019_apr_weekend_max', '2019_apr_weekend_min', '2019_apr_weekend_count', '2019_apr_weekend_stddev_samp', '2019_aug_weekday_sum', '2019_aug_weekday_avg', '2019_aug_weekday_max', '2019_aug_weekday_min', '2019_aug_weekday_count', '2019_aug_weekday_stddev_samp', '2019_aug_weekend_sum', '2019_aug_weekend_avg', '2019_aug_weekend_max', '2019_aug_weekend_min', '2019_aug_weekend_count', '2019_aug_weekend_stddev_samp', '2019_dec_weekday_sum', '2019_dec_weekday_avg', '2019_dec_weekday_max', '2019_dec_weekday_min', '2019_dec_weekday_count', '2019_dec_weekday_stddev_samp', '2019_dec_weekend_sum', '2019_dec_weekend_avg', '2019_dec_weekend_max', '2019_dec_weekend_min', '2019_dec_weekend_count', '2019_dec_weekend_stddev_samp', '2019_feb_weekday_sum', '2019_feb_weekday_avg', '2019_feb_weekday_max', '2019_feb_weekday_min', '2019_feb_weekday_count', '2019_feb_weekday_stddev_samp', '2019_feb_weekend_sum', '2019_feb_weekend_avg', '2019_feb_weekend_max', '2019_feb_weekend_min', '2019_feb_weekend_count', '2019_feb_weekend_stddev_samp', '2019_jan_weekday_sum', '2019_jan_weekday_avg', '2019_jan_weekday_max', '2019_jan_weekday_min', '2019_jan_weekday_count', '2019_jan_weekday_stddev_samp', '2019_jan_weekend_sum', '2019_jan_weekend_avg', '2019_jan_weekend_max', '2019_jan_weekend_min', '2019_jan_weekend_count', '2019_jan_weekend_stddev_samp', '2019_jul_weekday_sum', '2019_jul_weekday_avg', '2019_jul_weekday_max', '2019_jul_weekday_min', '2019_jul_weekday_count', '2019_jul_weekday_stddev_samp', '2019_jul_weekend_sum', '2019_jul_weekend_ ...

# %% [markdown]
# # Number of dataframes concated:

# %%
len(df_list)  # No of dataframes joined to get one merged_df
# Out:
# 17

# %% [markdown]
# #  Filtering the features related to particular Sub Category

# %%
for i in feature_df.columns:
    if(('restaurant' in i) == False) & ((i in brand_list)== False):
        feature_df=feature_df.drop(i)

# %%
#exporting feature dataset to excel file

feature_df.toPandas().to_excel("feature_2-yrs.xlsx")
